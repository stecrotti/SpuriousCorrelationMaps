# %%
import os
import pandas as pd

import sys
from pathlib import Path
sys.path.append(str(Path(os.getcwd()).absolute().parent))
from utils import *

# %%
# from https://www.kaggle.com/datasets/nelgiriyewithana/billionaires-statistics-dataset

df_in = pd.read_csv('billionaires_statistics_dataset.csv')
df_in.head()
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# ...

# %%
# produce a dataframe with countries and number of billionaires in each
df = df_in['country'].value_counts().reset_index()
df.rename(columns={'country': 'Country', 'count': 'Number of billionaires'}, inplace=True)

# %%
df = correct_country_names(df)

# %%
df
# Out:
#                      Country  Number of billionaires
# 0   United States of America                     754
# 1                      China                     523
# 2                      India                     157
# 3                    Germany                     102
# 4             United Kingdom                      82
# ..                       ...                     ...
# 73  Turks and Caicos Islands                       1
# 74                  Tanzania                       1
# 75                   Bahrain                       1
# 76                   Andorra                       1
# 77                   Armenia                       1
#
# [78 rows x 2 columns]

# %%
df.to_csv('billionaires_SCMdataset.csv', index = False)
